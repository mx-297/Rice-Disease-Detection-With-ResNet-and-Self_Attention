# %%
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/train.zip
# Out:
# Archive:  /content/gdrive/MyDrive/train.zip
#   inflating: train/id_004wknd7qd.jpg
#   inflating: train/id_005sitfgr2.jpg
#   inflating: train/id_00stp9t6m6.jpg
#   inflating: train/id_012zxewnhx.jpg
#   inflating: train/id_0186qwq2at.jpg
#   inflating: train/id_01vb9vty05.jpg
#   inflating: train/id_01z6i8am9b.jpg
#   inflating: train/id_02lw7skww5.jpg
#   inflating: train/id_02olqz4tf5.jpg
#   inflating: train/id_03878to61t.jpg
#   inflating: train/id_04alcsykf1.jpg
#   inflating: train/id_04lhl9cypv.jpg
#   inflating: train/id_05udbcy9yj.jpg
#   inflating: train/id_06lh8r7g0p.jpg
#   inflating: train/id_06nrnxmqfw.jpg
#   inflating: train/id_06ya2x9n2i.jpg
#   inflating: train/id_08of6gx23n.jpg
#   inflating: train/id_08rn3cmwlk.jpg
#   inflating: train/id_09sjnce7rh.jpg
#   inflating: train/id_0b3wfufkrn.jpg
#   inflating: train/id_0b9myv7d84.jpg
#   inflating: train/id_0brsi9wkxu.jpg
#   inflating: train/id_0c29p9v7sv.jpg
#   inflating: train/id_0ch8257gec.jpg
#   inflating: train/id_0d2iguix1u.jpg
#   inflating: train/id_0d6zji749f.jpg
#   inflating: train/id_0e0h5rmcrc.jpg
#   inflating: train/id_0e1ftfk5dn.jpg
#   inflating: train/id_0e3fpywz1c.jpg
#   inflating: train/id_0elx409mfe.jpg
#   inflating: train/id_0ez1rb5d66.jpg
#   inflating: train/id_0fq83cw58m.jpg
#   inflating: train/id_0hekyy5bpe.jpg
#   inflating: train/id_0hyxh5b0u4.jpg
#   inflating: train/id_0iedaup7qi.jpg
#   inflating: train/id_0iq6qeyl1w.jpg
#   inflating: train/id_0j77fcidk8.jpg
#   inflating: train/id_0jbcvl994p.jpg
#   inflating: train/id_0jkkhi50wx.jpg
#   inflating: train/id_0jpbgzxzqn.jpg
#   inflating: train/id_0jy0churxc.jpg
#   inflating: train/id_0jyq9bzwk7.jpg
#   inflating: train/id_0l62hcuzm1.jpg
#   inflating: train/id_0l8i75umhc.jpg
#   inflating: train/id_0mpknci13k.jpg
#   inflating: train/id_0mw1rk52n5.jpg
#   inflating: train/id_0mxgeykc2o.jpg
#   inflating: train/id_0myvk2ag4l.jpg
#   inflating: train/id_0nia20ywdy.jpg
#   inflating: train/id_0nnu7uivc9.jpg
#   inflating: train/id_0ocimw5rd9.jpg
#   inflating: train/id_0on7ehcfs6.jpg
#   inflating: train/id_0qqjl92ak2.jpg
#   inflating: train/id_0qvf8osgu2.jpg
#   inflating: train/id_0r3pohuvp7.jpg
#   inflating: train/id_0rd5eo3nlk.jpg
#   inflating: train/id_0rii8hoel4.jpg
#   inflating: train/id_0rt7042emf.jpg
#   inflating: train/id_0s75euu5br.jpg
#   inflating: train/id_0scncwcx6o.jpg
#   inflating: train/id_0sil0chxq2.jpg
#   inflating: train/id_0siwx1jy2o.jpg
#   inflating: train/id_0tmckthy7o.jpg
#   inflating: train/id_0uln9eczp7.jpg
#   inflating: train/id_2jstua0yxr.jpg
#   inflating: train/id_2k0n8ihd2n.jpg
#   inflating: train/id_2khkze9nns.jpg
#   inflating: train/id_2llgcxkba1.jpg
#   inflating: train/id_2mtep1z4l5.jpg
#   inflating: train/id_2mymunmmxo.jpg
#   inflating: train/id_2n4dzm42n3.jpg
#   inflating: train/id_2o86r4dt8g.jpg
#   inflating: train/id_2opzwh9ch1.jpg
#   inflating: train/id_2pgr55z9vm.jpg
#   inflating: train/id_2qcyhmu9eh.jpg
#   inflating: train/id_2qemwbu6im.jpg
#   inflating: train/id_2sng029vcf.jpg
#   inflating: train/id_2vw3ddwfes.jpg
#   inflating: train/id_2w4wxbmyd7.jpg
#   inflating: train/id_2wazj6g1mb.jpg
#   inflating: train/id_2wxwvdvjvy.jpg
#   inflating: train/id_2x0cy7cbys.jpg
#   inflating: train/id_2x90ukkbbh.jpg
#   inflating: train/id_2xy1nmieiy.jpg
#   inflating: train/id_2ydnr42cgy.jpg
#   inflating: train/id_2yym93q8wu.jpg
#   inflating: train/id_2zboxtuuw7.jpg
#   inflating: train/id_2zcwzu192u.jpg
#   inflating: train/id_2zhnxx8p4t.jpg
#   inflating: train/id_2zp81669e8.jpg
#   inflating: train/id_30bt94rxno.jpg
#   inflating: train/id_30fya4ma8i.jpg
#   inflating: train/id_30lsrc1y1a.jpg
#   inflating: train/id_314z20dac3.jpg
#   inflating: train/id_3188ia4uci.jpg
#   inflating: train/id_31c9pz05co.jpg
#   inflating: train/id_31p3zk5bof.jpg
#   inflating: train/id_326cpnnell.jpg
#   inflating: train/id_327notunp4.jpg
#   inflating: train/id_32axhj56lq.jpg
#   inflating: train/id_32ihs47q1q.jpg
#   inflating: train/id_32v7wc368g.jpg
#   inflating: train/id_33aril7ex3.jpg
#   inflating: train/id_33whvnnbub.jpg
#   inflating: train/id_348zgkhimv.jpg
#   inflating: train/id_34iwgxr20a.jpg
#   inflating: train/id_35q6ubuf8u.jpg
#   inflating: train/id_35s3rjqzf8.jpg
#   inflating: train/id_35tldm1ccf.jpg
#   inflating: train/id_363gqf95j5.jpg
#   inflating: train/id_36ir5ckm9r.jpg
#   inflating: train/id_36uo5n4dz2.jpg
#   inflating: train/id_36za75e469.jpg
#   inflating: train/id_37ue9qhky0.jpg
#   inflating: train/id_37us5l4vzf.jpg
#   inflating: train/id_38hw6224lp.jpg
#   inflating: train/id_38qabzsca8.jpg
#   inflating: train/id_38qm8agal5.jpg
#   inflating: train/id_39bxqjp7c9.jpg
#   inflating: train/id_39c2aki4jl.jpg
#   inflating: train/id_3a2fk3qz8y.jpg
#   inflating: train/id_3aypb1f08k.jpg
#   inflating: train/id_3bv1ij46k0.jpg
#   inflating: train/id_3bwykh2xhh.jpg
#   inflating: train/id_3cfrb55mhe.jpg
#   inflating: train/id_3cmghsnsl0.jpg
#   inflating: train/id_3dawyb9dn7.jpg
#   inflating: train/id_3dlurew9hv.jpg
#   inflating: train/id_3dravepz5j.jpg
#   inflating: train/id_3e4bjiblls.jpg
#   inflating: train/id_e8tmtp83rw.jpg
#   inflating: train/id_e9ne73wh9y.jpg
#   inflating: train/id_e9phhzzkjn.jpg
#   inflating: train/id_e9unacqi32.jpg
#   inflating: train/id_eais3vt8kh.jpg
#   inflating: train/id_eakyx4t62w.jpg
#   inflating: train/id_ec3bbgbajo.jpg
#   inflating: train/id_echyz1on6x.jpg
#   inflating: train/id_ecvj7qr7zp.jpg
#   inflating: train/id_ed2bnjciko.jpg
#   inflating: train/id_edh6bbs7mq.jpg
#   inflating: train/id_edj57v6oba.jpg
#   inflating: train/id_edkp2o2yb7.jpg
#   inflating: train/id_edswstwp53.jpg
#   inflating: train/id_eeepsnfstw.jpg
#   inflating: train/id_efi1b7c7mi.jpg
#   inflating: train/id_egbv7wusem.jpg
#   inflating: train/id_egeejqmrrm.jpg
#   inflating: train/id_egjpiuirdr.jpg
#   inflating: train/id_eh0wiew1ll.jpg
#   inflating: train/id_eh57bni16h.jpg
#   inflating: train/id_eisa0j37bh.jpg
#   inflating: train/id_ej8nzy74ph.jpg
#   inflating: train/id_ejoxnm4ldx.jpg
#   inflating: train/id_eksydcihho.jpg
#   inflating: train/id_el8sk5sno2.jpg
#   inflating: train/id_el9lv63hkl.jpg
#   inflating: train/id_elaw9wuzlx.jpg
#   inflating: train/id_emuegtbf62.jpg
#   inflating: train/id_enit3bpqsd.jpg
#   inflating: train/id_enk2wrtf6e.jpg
#   inflating: train/id_eoaoqrcmt2.jpg
#   inflating: train/id_eod1rxo7kt.jpg
#   inflating: train/id_eohrxc15nl.jpg
#   inflating: train/id_epg0mhn8k0.jpg
#   inflating: train/id_epn3kdoyws.jpg
#   inflating: train/id_epy73357s2.jpg
#   inflating: train/id_eq2dynzapx.jpg
#   inflating: train/id_eq6rq3lxar.jpg
#   inflating: train/id_er0il8ybn7.jpg
#   inflating: train/id_erqu30av6a.jpg
#   inflating: train/id_ertw9u2pou.jpg
#   inflating: train/id_es5flma69j.jpg
#   inflating: train/id_es9egfkdwv.jpg
#   inflating: train/id_esuvw5weuz.jpg
#   inflating: train/id_eszrmq679i.jpg
#   inflating: train/id_eu1tyvw6dn.jpg
#   inflating: train/id_eujhencwgu.jpg
#   inflating: train/id_eumixzoqz2.jpg
#   inflating: train/id_euzlag4tge.jpg
#   inflating: train/id_ev2npdlw09.jpg
#   inflating: train/id_evmuairbtx.jpg
#   inflating: train/id_ewcbmgzufv.jpg
#   inflating: train/id_ewevtooscw.jpg
#   inflating: train/id_ewmt3dkh3k.jpg
#   inflating: train/id_exaim5numk.jpg
#   inflating: train/id_exqdwompsl.jpg
#   inflating: train/id_exvnfv4ugx.jpg
#   inflating: train/id_exzabvss9s.jpg
#   inflating: train/id_eypjnso08u.jpg
#   inflating: train/id_eyth7gmtgj.jpg
#   inflating: train/id_eyxgh25aok.jpg
#   inflating: train/id_eyyfj1wn2b.jpg
#   inflating: train/id_ezrd2bru3u.jpg
#   inflating: train/id_ezw6en1dka.jpg
#   inflating: train/id_f00jousdpq.jpg
#   inflating: train/id_f18db1x189.jpg
#   inflating: train/id_vm5oa82j4j.jpg
#   inflating: train/id_vmmci3blon.jpg
#   inflating: train/id_vnvjk0hg90.jpg
#   inflating: train/id_vo8dzyx5hg.jpg
#   inflating: train/id_vo8hmt8hk3.jpg
#   inflating: train/id_voc5px7x4w.jpg
#   inflating: train/id_vov5gyqf7l.jpg
#   inflating: train/id_voy1pwsh9f.jpg
#   inflating: train/id_vpeisdv601.jpg
#   inflating: train/id_vqhhklaeop.jpg
#   inflating: train/id_vrmf76c6cy.jpg
#   inflating: train/id_vsu9c1ro3u.jpg
#   inflating: train/id_vswjhohhfi.jpg
#   inflating: train/id_vszg5rvwbb.jpg
#   inflating: train/id_vucr7vfn1u.jpg
#   inflating: train/id_vv4xx6zg4g.jpg
#   inflating: train/id_vv5jw31p3v.jpg
#   inflating: train/id_vvi6zd5kce.jpg
#   inflating: train/id_vw4vmdsg8z.jpg
#   inflating: train/id_vw9mplfttv.jpg
#   inflating: train/id_vwmb4hgqko.jpg
#   inflating: train/id_vx11zqkjot.jpg
#   inflating: train/id_vxpjy22it8.jpg
#   inflating: train/id_vxuw8ob3vk.jpg
#   inflating: train/id_vy89v6fe7i.jpg
#   inflating: train/id_vyxlsyxwtr.jpg
#   inflating: train/id_vz9z01lzq4.jpg
#   inflating: train/id_w02anaqd5p.jpg
#   inflating: train/id_w2sze24opq.jpg
#   inflating: train/id_w2wa9vqpt0.jpg
#   inflating: train/id_w38ptgvl0m.jpg
#   inflating: train/id_w3nh3qk7fs.jpg
#   inflating: train/id_w3s6zoy5w3.jpg
#   inflating: train/id_w3wva9nkug.jpg
#   inflating: train/id_w4hrbgzy20.jpg
#   inflating: train/id_w4li9hey14.jpg
#   inflating: train/id_w4mk2ai75c.jpg
#   inflating: train/id_w4qxunkxbm.jpg
#   inflating: train/id_w5072zcr6c.jpg
#   inflating: train/id_w6077zpq3v.jpg
#   inflating: train/id_w6o6dyd5jr.jpg
#   inflating: train/id_w7jdryt7e5.jpg
#   inflating: train/id_w8c7df4gwi.jpg
#   inflating: train/id_w8tou2zyz7.jpg
#   inflating: train/id_w8ux2fpguk.jpg
#   inflating: train/id_w8vv442b0k.jpg
#   inflating: train/id_w9v12h5jjr.jpg
#   inflating: train/id_wauq2jfgv4.jpg
#   inflating: train/id_wbm2xujuv7.jpg
#   inflating: train/id_wbsi4nchsd.jpg
#   inflating: train/id_wbw2tyc0hj.jpg
#   inflating: train/id_wbx6clu31a.jpg
#   inflating: train/id_wc3k5053yc.jpg
#   inflating: train/id_wccudrbkqo.jpg
#   inflating: train/id_wcwrdymec5.jpg
#   inflating: train/id_wd0igdrvj3.jpg
#   inflating: train/id_wdn9zvj8ar.jpg
#   inflating: train/id_weo7yarj80.jpg
#   inflating: train/id_wew56td4hr.jpg
#   inflating: train/id_wfgfdsbvpr.jpg
#   inflating: train/id_wfgg5mv3i6.jpg
#   inflating: train/id_wfsoaqsuc4.jpg
#   inflating: train/id_wfyyk5h1i6.jpg
#   inflating: train/id_wgi3xm3wm5.jpg
#   inflating: train/id_xdfitwp6xj.jpg
#   inflating: train/id_xdg7c8btgn.jpg
#   inflating: train/id_xh461un1cm.jpg
#   inflating: train/id_xhh2e7a3id.jpg
#   inflating: train/id_xiyzmnezfq.jpg
#   inflating: train/id_xjj0pqb70h.jpg
#   inflating: train/id_xjowebu3xp.jpg
#   inflating: train/id_xkr1n7uvdc.jpg
#   inflating: train/id_xkvb3hd5sf.jpg
#   inflating: train/id_xlc6b474tp.jpg
#   inflating: train/id_xls89lrwdh.jpg
#   inflating: train/id_xmeknmv7ol.jpg
#   inflating: train/id_xmls4vs93p.jpg
#   inflating: train/id_xn0uve1bk8.jpg
#   inflating: train/id_xnmxbcsoj1.jpg
#   inflating: train/id_xo5wyxw9xm.jpg
#   inflating: train/id_xojhu7rhry.jpg
#   inflating: train/id_xomxs0bgxh.jpg
#   inflating: train/id_xopwepvln7.jpg
#   inflating: train/id_xpzgppmlt3.jpg
#   inflating: train/id_xpzi6efwa2.jpg
#   inflating: train/id_xq8lhes7n5.jpg
#   inflating: train/id_xqt1jmkpwx.jpg
#   inflating: train/id_xr61p8cmni.jpg
#   inflating: train/id_xrxp83p0xn.jpg
#   inflating: train/id_xtq70h3oay.jpg
#   inflating: train/id_xtrusj5mo4.jpg
#   inflating: train/id_xu0m1pyu87.jpg
#   inflating: train/id_xuarpa5b37.jpg
#   inflating: train/id_xvac7hhejn.jpg
#   inflating: train/id_xvbe5cjpc0.jpg
#   inflating: train/id_xvdttwg7zm.jpg
#   inflating: train/id_xveb20haup.jpg
#   inflating: train/id_xvirmx1vra.jpg
#   inflating: train/id_xvoyuffhsw.jpg
#   inflating: train/id_xvvv626x80.jpg
#   inflating: train/id_xwddj5qmqw.jpg
#   inflating: train/id_xx0q2hodej.jpg
#   inflating: train/id_xxw8xumc5x.jpg
#   inflating: train/id_xy4z5ps2tm.jpg
#   inflating: train/id_y0349hr0u9.jpg
#   inflating: train/id_y1i2ij9n7o.jpg
#   inflating: train/id_y1soc1y068.jpg
#   inflating: train/id_y28o5af7gx.jpg
#   inflating: train/id_y2eb84bcju.jpg
#   inflating: train/id_y4lhs2l0zf.jpg
#   inflating: train/id_y56x2at4x7.jpg
#   inflating: train/id_y5s3tyns2h.jpg
#   inflating: train/id_y6mkyq3uhf.jpg
#   inflating: train/id_y77b12wfqd.jpg
#   inflating: train/id_y7cwabooh6.jpg
#   inflating: train/id_y8npsespvq.jpg
#   inflating: train/id_y8s5j8k08e.jpg
#   inflating: train/id_y8zpqd8ld1.jpg
#   inflating: train/id_y9oaejxl4o.jpg
#   inflating: train/id_y9wh4f1z62.jpg
#   inflating: train/id_y9xrdwzbak.jpg
#   inflating: train/id_yagf23qj2l.jpg
#   inflating: train/id_yaofgsoi7m.jpg
#   inflating: train/id_yaonlmohpr.jpg
#   inflating: train/id_yaqjk6xsk0.jpg
#   inflating: train/id_ybxhrwgscn.jpg
#   inflating: train/id_yc2bzswa9d.jpg
#   inflating: train/id_ychikq7opg.jpg
#   inflating: train/id_ycjb148t8o.jpg
#   inflating: train/id_zbk7cuy5dk.jpg
#   inflating: train/id_zc7jyiweh2.jpg
#   inflating: train/id_zcljbub8gi.jpg
#   inflating: train/id_zd11u52q7u.jpg
#   inflating: train/id_zd3ngmrvry.jpg
#   inflating: train/id_zd3yuiuwm8.jpg
#   inflating: train/id_zefo9un5o5.jpg
#   inflating: train/id_zepp4vfds6.jpg
#   inflating: train/id_zf10hw45ng.jpg
#   inflating: train/id_zfg9klnjyj.jpg
#   inflating: train/id_zfkzh6044j.jpg
#   inflating: train/id_zfo1iphvm3.jpg
#   inflating: train/id_zgha1bje1d.jpg
#   inflating: train/id_zgo6w5lt74.jpg
#   inflating: train/id_zil68oveco.jpg
#   inflating: train/id_zimfwn21j6.jpg
#   inflating: train/id_ziwywm8qtc.jpg
#   inflating: train/id_zj26sxb7iu.jpg
#   inflating: train/id_zja13qs1gz.jpg
#   inflating: train/id_zjlf1ugace.jpg
#   inflating: train/id_zk0fa3dsrg.jpg
#   inflating: train/id_zkvpjmdz1a.jpg
#   inflating: train/id_zkz5oykwrp.jpg
#   inflating: train/id_zlad37cdkm.jpg
#   inflating: train/id_zlstf86o30.jpg
#   inflating: train/id_zmhmoi0n5i.jpg
#   inflating: train/id_zmlohzmppc.jpg
#   inflating: train/id_znct4h27t1.jpg
#   inflating: train/id_znfjt0t7qv.jpg
#   inflating: train/id_znum4ijq9g.jpg
#   inflating: train/id_zo4j4fqyqh.jpg
#   inflating: train/id_zoltpbqze9.jpg
#   inflating: train/id_zow3gghj0l.jpg
#   inflating: train/id_zp1zke5qu7.jpg
#   inflating: train/id_zpsvn2vbnu.jpg
#   inflating: train/id_zqlkrd2wv9.jpg
#   inflating: train/id_zqo252mw0w.jpg
#   inflating: train/id_zrojwzhjp4.jpg
#   inflating: train/id_zry3h7m866.jpg
#   inflating: train/id_zt1a8nuesi.jpg
#   inflating: train/id_zt9xyhaobt.jpg
#   inflating: train/id_ztkgkz833l.jpg
#   inflating: train/id_zu1styzol0.jpg
#   inflating: train/id_zujzt9sjh8.jpg
#   inflating: train/id_zv0si9k8r7.jpg
#   inflating: train/id_zvmqpmv7z3.jpg
#   inflating: train/id_zw3dkayu0b.jpg
#   inflating: train/id_zw4xo2evq1.jpg
#   inflating: train/id_zw6hffbkis.jpg
#   inflating: train/id_zwgjls96ev.jpg
#   inflating: train/id_zwo2havuv5.jpg
#   inflating: train/id_zxhpss7ytr.jpg
#   inflating: train/id_zy9n6xce9p.jpg
#   inflating: train/id_zydzdp046u.jpg
#   inflating: train/id_zyoowbqcm3.jpg
#   inflating: train/id_zz6gzk7p97.jpg
#   inflating: train/id_zz8ca2p67e.jpg
#   inflating: train/id_zzt8y9q0x0.jpg

# %%
import pandas as pd
train_df = pd.read_csv("Train.csv")
train_df.head()
# Out:
#                 Image_id  Label
# 0      id_004wknd7qd.jpg  blast
# 1  id_004wknd7qd_rgn.jpg  blast
# 2      id_005sitfgr2.jpg  brown
# 3  id_005sitfgr2_rgn.jpg  brown
# 4      id_00stp9t6m6.jpg  blast

# %%
train_df.drop(axis = 0, index = [i for i in range(1,train_df.shape[0],2)], inplace = True)
train_df = train_df.reset_index()
train_df.drop('index',axis = 1, inplace = True)
train_df.head()
# Out:
#             Image_id    Label
# 0  id_004wknd7qd.jpg    blast
# 1  id_005sitfgr2.jpg    brown
# 2  id_00stp9t6m6.jpg    blast
# 3  id_012zxewnhx.jpg    blast
# 4  id_0186qwq2at.jpg  healthy

# %%
train_df['Label'].value_counts()
# Out:
# blast      1494
# brown       766
# healthy     410
# Name: Label, dtype: int64

# %%
train_df['Label_int'] = train_df['Label'].replace(['blast','brown','healthy'], [0,1,2])
train_df
# Out:
#                Image_id    Label  Label_int
# 0     id_004wknd7qd.jpg    blast          0
# 1     id_005sitfgr2.jpg    brown          1
# 2     id_00stp9t6m6.jpg    blast          0
# 3     id_012zxewnhx.jpg    blast          0
# 4     id_0186qwq2at.jpg  healthy          2
# ...                 ...      ...        ...
# 2665  id_zydzdp046u.jpg  healthy          2
# 2666  id_zyoowbqcm3.jpg  healthy          2
# 2667  id_zz6gzk7p97.jpg    brown          1
# 2668  id_zz8ca2p67e.jpg    blast          0
# 2669  id_zzt8y9q0x0.jpg    brown          1
#
# [2670 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(train_df['Image_id'],train_df['Label_int'], test_size=0.3, random_state=1234)

# %%
from torchvision import transforms

train_transform = transforms.Compose([
        transforms.RandomVerticalFlip(),      
        transforms.RandomHorizontalFlip(),  
        transforms.Resize(224),             
        transforms.CenterCrop(224),        
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

val_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

# %%
import os
import torch
from torch.utils.data import Dataset
from torchvision.io import read_image
import cv2
from PIL import Image

class Rice_Dataset(Dataset):

    def __init__(self, images, labels, img_dir,transform):

        self.labels = labels
        self.img_dir = img_dir
        self.images = images
        self.transform = transform

    def __len__(self):

        return len(self.images)

    def __getitem__(self,idx):

        img_path = os.path.join(self.img_dir, self.images[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(img)
        img = self.transform(img)
        label = torch.tensor(self.labels[idx])

        return img, label

# %%
train_dataset = Rice_Dataset(X_train.values, y_train.values, "/content/train/",transform = train_transform)
valid_dataset = Rice_Dataset(X_val.values, y_val.values, "/content/train/",transform = val_transform)

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(train_dataset, batch_size=150, shuffle=True)
valid_dataloader = DataLoader(valid_dataset, batch_size = 150, shuffle = False)

# %%
import matplotlib.pyplot as plt
import torchvision
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")

# fig,axs = plt.subplots(3,3)
# plt.subplots_adjust(wspace=0.5, hspace=0.4)
# for i in range(3):

#     for j in range(3):

#         img = train_features[i + j + i*2].squeeze()
#         label = train_labels[i + j + i*2 ]
#         if label == 0:
            
#             label = "blast"
        
#         elif label == 1:

#             label = "brown"
        
#         else:

#             label = "healthy"

#         axs[i,j].imshow(img);
#         axs[i,j].set_title(f"{label}");
#         axs[i,j].axis('off')
# Out:
# Feature batch shape: torch.Size([150, 3, 224, 224])
# Labels batch shape: torch.Size([150])

# %% [markdown]
# **Building The Model**

# %%
import torch.nn as nn
import torch.nn.functional as F

class Attn(nn.Module):
    def __init__(self, in_features,up_factor):
        
        super(Attn, self).__init__()
        self.up_factor = up_factor
        self.op = nn.Conv2d(in_channels=in_features, out_channels=1, kernel_size=1, padding=0, bias=False)
    
    def forward(self, l, g):
        N, C, W, H = l.size()
        g = F.interpolate(g, scale_factor = self.up_factor, mode = 'bilinear', align_corners = False)
        #print(l.size(),g.size())
        c = self.op(l+g) # batch_sizex1xWxH
    
        a = F.softmax(c.view(N,1,-1), dim=2).view(N,1,W,H)
        g = torch.mul(a.expand_as(l), l)
        g = g.view(N,C,-1).sum(dim=2) # batch_sizexC
    
        return a, g

# %%
class ProjectorBlock(nn.Module):
    def __init__(self, in_features, out_features):
        
        super(ProjectorBlock, self).__init__()
        
        self.op = nn.Conv2d(in_channels=in_features, out_channels=out_features, kernel_size=1, padding=0, bias=False)
    
    def forward(self, inputs):
        
        return self.op(inputs)

# %%
import torchvision.models as models
import torch 

class Attn_ResNet34(nn.Module):

    def __init__(self,num_classes):
        
        super(Attn_ResNet34, self).__init__()

        base_model = models.resnet34(weights = "IMAGENET1K_V1")

        layers = list(base_model.children())

        self.conv1 = nn.Sequential(*layers[0:3])

        self.conv2 = nn.Sequential(*layers[3:5])

        self.conv3 = layers[5]

        self.conv4 = layers[6]

        self.conv5 = layers[7]

        self.drp1 = nn.Dropout(0.3)
        self.drp2 = nn.Dropout(0.4)

        self.pool  = nn.AdaptiveAvgPool2d((1,1))

        self.cls = nn.Linear(in_features = 512*3, out_features = num_classes, bias = True)

        self.projector1 = ProjectorBlock(128,512)
        self.projector2 = ProjectorBlock(256,512)

        self.attn1 = Attn(512,4)
        self.attn2 = Attn(512,2)

    def forward(self,x):

        x = self.conv1(x)
        x = self.conv2(x)
        l1 = self.conv3(x)
        l2 = self.conv4(l1)
        x = self.conv5(l2)
        
        N, __, __, __ = x.size()
        g = self.pool(x).view(N,512)

        #print(x.size(),g.size(),l1.size(),l2.size())

        a1,g1 = self.attn1(self.projector1(l1),x)
        a2,g2 = self.attn2(self.projector2(l2),x)

        g = torch.cat((g,g1,g2), dim = 1)

        g = self.drp1(g)
        g = self.drp2(g)

        x = self.cls(g)
        
        x = F.softmax(x,dim = 1)

        return x,a1,a2

# %%
x = Attn_ResNet34(3)

# %%
import torch.optim as optim
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_labels = np.unique(y_train.values)
class_weights = compute_class_weight(class_weight = 'balanced', classes = class_labels, y = y_train.values)
class_weights = torch.from_numpy(class_weights).float()
criterion = nn.CrossEntropyLoss(class_weights)
optimizer = optim.Adam(x.parameters(), lr=0.001)

# %%
train_loss = []
val_loss = []
best_loss = 1000

for epoch in range(30):  # loop over the dataset multiple times

    Average_train_loss_per_epoch = 0.0
    Average_val_loss_per_epoch = 0.0

    for i, data in enumerate(train_dataloader, 0):
        
        running_train_loss_per_batch = 0.0
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs,_,_ = x(inputs)
        
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_train_loss_per_batch += loss.item()
        Average_train_loss_per_epoch += running_train_loss_per_batch

        print(f'[{epoch + 1}, {i+1:3d}] loss: {running_train_loss_per_batch}')
    
    print("\n")
    print(f'epoch[{epoch + 1}] loss: {Average_train_loss_per_epoch / len(train_dataloader)}')
    train_loss.append(Average_train_loss_per_epoch / len(train_dataloader))
    print("\n")

    with torch.no_grad():
        
        for i, test_data in enumerate(valid_dataloader,0):
            
            running_val_loss_per_batch = 0.0

            val_inputs,val_labels = test_data

            y_val,_,_ = x(val_inputs)

            loss = criterion(y_val,val_labels)
            
            running_val_loss_per_batch+=loss.item()
            Average_val_loss_per_epoch+=running_val_loss_per_batch
    
    val_loss_per_epoch = Average_val_loss_per_epoch / len(valid_dataloader)
    print(f'epoch[{epoch + 1}] val_loss: {val_loss_per_epoch}')
    val_loss.append(val_loss_per_epoch)
    if(val_loss_per_epoch < best_loss):

      torch.save(x.state_dict(),"./rice.h5")
      best_loss = val_loss_per_epoch


print('Finished Training')
# Out:
# [1,   1] loss: 1.0879820585250854
# [1,   2] loss: 0.9798263311386108
# [1,   3] loss: 0.9553542733192444
# [1,   4] loss: 0.9123198390007019
# [1,   5] loss: 0.9048238396644592
# [1,   6] loss: 0.8693256378173828
# [1,   7] loss: 0.8233543634414673
# [1,   8] loss: 0.8511172533035278
# [1,   9] loss: 0.8602757453918457
# [1,  10] loss: 0.7883673906326294
# [1,  11] loss: 0.8002716302871704
# [1,  12] loss: 0.889166533946991
# [1,  13] loss: 0.8612455725669861
#
#
# epoch[1] loss: 0.8910331130027771
#
#
# epoch[1] val_loss: 0.8568168481191
# [2,   1] loss: 0.8051918148994446
# [2,   2] loss: 0.7758727073669434
# [2,   3] loss: 0.8389503359794617
# [2,   4] loss: 0.857072114944458
# [2,   5] loss: 0.7895267009735107
# [2,   6] loss: 0.7558169960975647
# [2,   7] loss: 0.8187352418899536
# [2,   8] loss: 0.8413940072059631
# [2,   9] loss: 0.8748893141746521
# [2,  10] loss: 0.8953260779380798
# [2,  11] loss: 0.831976592540741
# [2,  12] loss: 0.7949177026748657
# [2,  13] loss: 0.7977232336997986
#
#
# epoch[2] loss: 0.8213379107988797
#
#
# epoch[2] val_loss: 0.8563525279362997
# [3,   1] loss: 0.8278202414512634
# [3,   2] loss: 0.7517217993736267
# [3,   3] loss: 0.7946022152900696
# [3,   4] loss: 0.714256227016449
# [3,   5] loss: 0.7622249722480774
# [3,   6] loss: 0.7636069059371948
# [3,   7] loss: 0.8401293754577637
# [3,   8] loss: 0.7847654819488525
# [3,   9] loss: 0.7471559047698975
# [3,  10] loss: 0.8290097117424011
# [3,  11] loss: 0.7681235671043396
# [3,  12] loss: 0.8095752596855164
# [3,  13] loss: 0.7613033652305603
#
#
# epoch[3] loss: 0.7810996174812317
#
#
# epoch[3] val_loss: 0.8217267394065857
# [4,   1] loss: 0.8029360771179199
# [4,   2] loss: 0.7342416048049927
# [4,   3] loss: 0.7977761030197144
# [4,   4] loss: 0.7051129341125488
# [4,   5] loss: 0.7363244295120239
# [4,   6] loss: 0.7582587599754333
# [4,   7] loss: 0.697125256061554
# [4,   8] loss: 0.737838864326477
# [4,   9] loss: 0.7658133506774902
# [4,  10] loss: 0.745512843132019
# [4,  11] loss: 0.7017828226089478
# [4,  12] loss: 0.7613523602485657
# [4,  13] loss: 0.8321540355682373
#
#
# epoch[4] loss: 0.7520176493204557
#
#
# epoch[4] val_loss: 0.7989787558714548
# [5,   1] loss: 0.7756639719009399
# [15,   2] loss: 0.6798951625823975
# [15,   3] loss: 0.7474560141563416
# [15,   4] loss: 0.6923367977142334
# [15,   5] loss: 0.6843889355659485
# [15,   6] loss: 0.693597137928009
# [15,   7] loss: 0.7085407376289368
# [15,   8] loss: 0.7394339442253113
# [15,   9] loss: 0.7260951399803162
# [15,  10] loss: 0.6949967741966248
# [15,  11] loss: 0.763327956199646
# [15,  12] loss: 0.705845296382904
# [15,  13] loss: 0.6776455640792847
#
#
# epoch[15] loss: 0.7109964719185462
#
#
# epoch[15] val_loss: 0.7470157047112783
# [16,   1] loss: 0.644409716129303
# [16,   2] loss: 0.6886775493621826
# [16,   3] loss: 0.6786399483680725
# [16,   4] loss: 0.6930164694786072
# [16,   5] loss: 0.6690524220466614
# [16,   6] loss: 0.7214207053184509
# [16,   7] loss: 0.6909185647964478
# [16,   8] loss: 0.7130868434906006
# [16,   9] loss: 0.6844156980514526
# [16,  10] loss: 0.688309907913208
# [16,  11] loss: 0.7092882394790649
# [16,  12] loss: 0.7520001530647278
# [16,  13] loss: 0.6873388290405273
#
#
# epoch[16] loss: 0.6938903881953313
#
#
# epoch[16] val_loss: 0.7778780261675516
# [17,   1] loss: 0.7380273342132568
# [17,   2] loss: 0.7246434688568115

# %%
#PATH = './rice_net.pth'
#torch.save(x.state_dict(), PATH)

# %%
# !unzip /content/gdrive/MyDrive/Rice/test.zip

# %%
test_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

# %%
class Rice_Dataset_Test(Dataset):

    def __init__(self, images, img_dir,transform):

        self.img_dir = img_dir
        self.images = images
        self.transform = transform

    def __len__(self):

        return len(self.images)

    def __getitem__(self,idx):

        img_path = os.path.join(self.img_dir, self.images[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(img)
        img = self.transform(img)
        image_name = self.images[idx]

        return img,image_name

# %%
test_df = pd.read_csv("Test.csv")
test_df

# %%
test_df.drop(axis = 0, index = [i for i in range(1,test_df.shape[0],2)], inplace = True)
test_df.reset_index(inplace = True)
test_df.drop('index',axis = 1, inplace = True)
test_df

# %%
test_dataset = Rice_Dataset_Test(test_df['Image_id'].values,"/content/test/",transform = test_transform )

# %%
test_dataloader = DataLoader(test_dataset, batch_size = 150, shuffle = False)

# %%
x = Attn_ResNet34(3)
x.load_state_dict(torch.load(PATH))
x.eval()

# %%
df = {'Image_id':[], 'blast':[], 'brown':[], 'healthy':[]}

with torch.no_grad():

    for data in test_dataloader:

        images,names = data

        outputs,_,_ = x(images)

        _,predicted = torch.max(outputs,1)

        for i in range(len(predicted)):

            df['Image_id'].append(names[i])

            if(predicted[i] == 0):

                df['blast'].append(1)
                df['brown'].append(0)
                df['healthy'].append(0)

            elif(predicted[i] == 1):

                df['blast'].append(0)
                df['brown'].append(1)
                df['healthy'].append(0)

            else:

                df['blast'].append(0)
                df['brown'].append(0)
                df['healthy'].append(1)


submission = pd.DataFrame(df)

# %%
submission

# %%
from google.colab import files
submission.to_csv('submission.csv', encoding = 'utf-8-sig') 
#files.download('output.csv')

# %%
a = torch.rand(150,3)
a

# %%
a = F.softmax(a,dim = 1)

# %%
a
